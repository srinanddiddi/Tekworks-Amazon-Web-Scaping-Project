# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import re

# %%
url = "https://www.amazon.in/s?k=laptop&crid=1YL3M5YH4DUVH&sprefix=laptop%2Caps%2C366&ref=nb_sb_noss_2"

# %%
headers={
    "User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/144.0.0.0 Safari/537.36"
}

# %%
data=[]

# %%
response=requests.get(url,headers=headers)
response.status_code
# Out:
# 200

# %%
import time


for page in range(1,3):
    params = {'k': 'laptop', 'page': page}
    response = requests.get(url, headers=headers, params=params)
    soup = BeautifulSoup(response.content, 'html.parser')

    products= soup.find_all('div', {'data-component-type': 's-search-result'})

    # extract the title
    for product in products:
        title_tag = product.find("h2")

        if not title_tag:
           continue
        title_text = title_tag.get_text(strip=True)

        price_tag = product.find("span", {"class": "a-price-whole"})
        price_text = price_tag.get_text(strip=True) if price_tag else "N/A"

        data.append({
            "Title":title_text,
            "Price":price_text
        })

    print(f"Page {page} scraped")
    time.sleep(1)
# Out:
# Page 1 scraped
# Page 2 scraped

# %%
# extracting the brand form the title
for product in data:
    title = product["Title"]
    # Simple brand extraction assuming brand is the first word in the title
    brand = title.split()[0] if title else "Unknown"
    product["Brand"] = brand
    # extract the ram from the title
for product in data:
    title = product["Title"]
    ram_match = re.search(r'(\d+)\s*GB\s*(RAM|DDR\d+|LPDDR\d+)', title)
    ram = ram_match.group(1) if ram_match else "N/A"
    product["RAM"] = ram
for product in data:
    print("Title: ",product["Title"])
    print("Price: ",product["Price"])
    print("Brand: ",product["Brand"])
    print("RAM: ",product["RAM"])
    print("-"*80)
# Out:
# Title:  HP OmniBook 5 OLED (Previously Pavilion), Snapdragon X Processor (16GB LPDDR5x, 512GB SSD) 2K, 14''/35.6cm, Win11, M365 Basic(1yr)* Office24, Silver, 1.35kg, he0014QU, Light-Weight, Next-Gen AI Laptop
# Price:  66,990
# Brand:  HP
# RAM:  16
# --------------------------------------------------------------------------------
# Title:  Lenovo IdeaPad Slim 3 13th Gen Core i7-13620H 15.3" (38.8cm) WUXGA IPS Laptop (24GB RAM/1TB SSD/Win 11/Office 2024/Backlit/1Yr ADP Free/Top Metal Cover & IR Camera/Grey/1.6Kg),83K100TEIN
# Price:  90,990
# Brand:  Lenovo
# RAM:  24
# --------------------------------------------------------------------------------
# Title:  EBook 11.6" HD Laptop | Best Student & Office Work Laptop | Celeron N4020 | 4GB DDR4 | 128GB eMMC + M.2 SSD Expandable Slot | Win 11 Home |31Wh Battery | UHD Graphics 600 | Black
# Price:  10,990
# Brand:  EBook
# RAM:  4
# --------------------------------------------------------------------------------
# Title:  BrowseBook 14.1" FHD IPS Laptop | Best Student & Office Work Laptop | Celeron N4020 | 4GB RAM | 128GB SSD | Windows 11 | 38Wh | 1.3kg | Grey
# Price:  12,990
# Brand:  BrowseBook
# RAM:  4
# --------------------------------------------------------------------------------
# Title:  JioBook 11 with Lifetime Office | Android 4G Laptop Mediatek 8788 (JioOS) | Octa-core | 4GB RAM | 64 eMMC Storage | Thin and Light Laptop (11.6 inch, 990 Grams) | Dual Band WiFi + SIM | Blue
# Price:  10,990
# Brand:  JioBook
# RAM:  4
# --------------------------------------------------------------------------------
# Title:  HP 15, 13th Gen Intel Core i3-1315U (12GB DDR4, 512GB SSD) FHD, Anti-Glare, Micro-Edge, 15.6''/39.6cm, Win11, M365 Basic(1yr)* Office24, Silver, 1.59kg, fd0573TU, FHD Camera w/Shutter Laptop
# Price:  41,990
# Brand:  HP
# RAM:  12
# --------------------------------------------------------------------------------
# Title:  HP 15, AMD Ryzen 3 7320U (8GB DDR4, 512GB SSD) FHD, Anti-Glare, Micro-Edge, 15.6''/39.6cm, Win11, M365 Basic(1yr)* Office24, Silver, 1.59kg, fc0500AU, FHD Camera w/Privacy Shutter Laptop
# Price:  36,990
# Brand:  HP
# RAM:  8
# --------------------------------------------------------------------------------
# Title:  Lenovo {SmartChoice)Chromebook Intel Celeron N4500 (4GB RAM/64GB eMMC 5.1/11.6 Inch (29.46cm)/HD Display/2Wx2 Stereo Speakers/HD Camera/Chrome OS/Blue/1.21Kg), 82UY0014HA
# Price:  N/A
# Brand:  Lenovo
# RAM:  4
# --------------------------------------------------------------------------------
# Title:  Thomson NEO 14.1 Inch IN-N14C Intel Celeron Dual Core N4020 Processor Windows 11 Home Notebook (8 GB RAM DDR4/ 256 GB SSD/Thin & Light Weight/Silver/Non Stop Performance Beyond 15 Hrs)
# Price:  17,990
# Brand:  Thomson
# RAM:  8
# --------------------------------------------------------------------------------
# Title:  HP 14s Intel Celeron Dual Core N4500 Laptop (8GB/512GB SSD/Win 11) 14.0" HD Display, MSO 24, Black, 1.46kg, DQ3149TU Thin and Light Business Laptop
# Price:  28,690
# Brand:  HP
# RAM:  N/A
# --------------------------------------------------------------------------------
# Title:  Dell 15, Intel Core i5 13th Gen-1334U Processor, 16GB DDR4, 512GB SSD, FHD, 15.6"/39.62cm, Windows 11, MSO 2024, Grey, 1.66kg, [Vostro 3530], 120Hz 250 nits, 15 Month McAfee, Thin & Light, Laptop
# Price:  56,990
# Brand:  Dell
# RAM:  16
# --------------------------------------------------------------------------------
# Title:  Lenovo IdeaPad 5 2-in-1 Convertible Laptop, Intel Core i7-13620H, 13th Gen, 16GB RAM, 512GB SSD, WUXGA OLED 400Nit, 14"/35.5cm, Windows 11, Office Home 2024, Grey, 1.5kg, 83KX004RIN, FPR, 1Yr ADP Free
# Price:  88,800
# Brand:  Lenovo
# RAM:  16
# --------------------------------------------------------------------------------
# Title:  HP 15 Consumer Series Laptop, Intel Core i3-1315U (13th Gen) 12GB DDR4 RAM,512GB NVMe SSD/ 15.6'' FHD Anti-Glare, Micro-Edge, Win11, M365 Basic(1yr)* Office24, Silver,1.59kg, FHD Camera with Shutter
# Price:  41,990
# Brand:  HP
# RAM:  12
# --------------------------------------------------------------------------------
# Title:  ASUS Vivobook 14, Intel Core i3 13th Gen 1315U, 8GB RAM, 512GB SSD, FHD 14", Windows 11, Office Home 2024, Cool Silver, 1.40kg, X1404VA-NK761WS, Intel UHD, M365 Basic (1Year)*, Backlit Keyboard Laptop
# Price:  36,675
# Brand:  ASUS
# RAM:  8
# --------------------------------------------------------------------------------
# Title:  ASUS Vivobook Go 14, AMD Ryzen 3 7320U, 8GB RAM, 512GB SSD, FHD 14", Windows 11, Office Home 2024, Mixed Black, 1.38 kg, E1404FA-NK3325WS, AMD Radeon iGPU, M365 Basic (1Year)*, Thin & Light Laptop
# Price:  34,790
# Brand:  ASUS
# RAM:  8
# --------------------------------------------------------------------------------
# Title:  Thomson NEO 14.1 Inch IN-P14C Intel Celeron Dual Core N4020 Processor & Window 11 Home Notebook (4 GB RAM DDR4/ 128 GB SSD/Numeric Touch Pad/Thin & Light Weight/Silver)
# Price:  12,990
# Brand:  Thomson
# RAM:  4
# --------------------------------------------------------------------------------
# Title:  HP 15 Laptop, AMD Ryzen 7 5825U [16GB DDR4,512GB SSD] [Win11, Office Home'2024/M365 Basic(1yr)*] [Anti-Glare,Micro-Edge,15.6''/39.6cm FHD]Silver,1.59kg [Backlit KB+FHD Camera+Radeon Graphics] fc0533AU
# Price:  49,990
# Brand:  HP
# RAM:  16
# --------------------------------------------------------------------------------
# Title:  acer Aspire 3, Intel Core Celeron N4500, 12GB LPDDR4X RAM, 512GB SSD, HD, 15.6"/39.62cm, Windows 11 Home, Pure Silver, 1.5KG, A325-45, Thin and Light Laptop
# Price:  31,999
# Brand:  acer
# RAM:  12
# --------------------------------------------------------------------------------
# Title:  Walker Best Student & Office Work Laptop|Thin & Light|15.6" 1920 * 1080 Resolution FHD IPS Display |8GB RAM,256 GB SSD|Intel Celeron Processor N4020 | Windows 11 Home |Silver
# Price:  16,990
# Brand:  Walker
# RAM:  8
# --------------------------------------------------------------------------------
# Title:  Dell 15, Intel Core i3 13th Gen -1305U, 16GB DDR4, 512GB SSD, FHD, 15.6"/39.6cm, Windows 11, Office H&S 2024, Carbon Grey, 1.66Kg, [Vostro 3530], Intel UHD Graphics, Narrow Border, Thin & Light Laptop
# Price:  42,990
# Brand:  Dell
# RAM:  16
# --------------------------------------------------------------------------------
# Title:  Ultimus APEX TwinX 2-in-1 Touchscreen Laptop 16 GB RAM 512 GB SSD Intel® Core™ i3-1215U, 27.8 cm x2 FHD Display, Win 11, Wi-Fi 6, Bluetooth 5.2, USB 3.2 Type-C with Stylus 1.2Kg Silver
# Price:  45,990
# Brand:  Ultimus
# RAM:  16
# --------------------------------------------------------------------------------
# Title:  Lenovo ThinkPad E14 Intel Core i7 13th Gen 14" WUXGA IPS 300 Nits Thin and Light Laptop (16GB RAM/512GB SSD/DOS/Backlit Keyboard/Fingerprint/Arctic Grey/ 1Y Onsite/1.41 kg), 21JKS1FR00
# Price:  82,490
# Brand:  Lenovo
# RAM:  16
# --------------------------------------------------------------------------------
# Title:  HP OmniBook 7 OLED, Intel Core Ultra 5 255H (16GB LPDDR5,1TB SSD), 3K, 0.2 ms, Micro-Edge, 14''/35.6cm, Win 11, M365, Office 24, Meteor Silver,1.5kg, fr0789TU, 5MP Camera w/Shutter, Backlit AI Laptop
# Price:  86,490
# Brand:  HP
# RAM:  16
# --------------------------------------------------------------------------------
# Title:  Dell 15, Intel Core i5 13th Gen-1334U Processor, 16GB DDR4, 512GB SSD, FHD, 15.6"/39.62cm, Windows 11, MSO 2024, Grey, 1.66kg, [Vostro 3530], 120Hz 250 nits, 15 Month McAfee, Thin & Light, Laptop
# Price:  56,990
# Brand:  Dell
# RAM:  16
# --------------------------------------------------------------------------------
# Title:  HP Smartchoice Omen AMD Ryzen 7 7840Hs, 8GB RTX 4060 (16GB DDR5, 1TB SSD) FHD, 165Hz, 300Nits, IPS, 16.1''/40.9cm, Win11, Office 21, Black, 2.32kg, Xd0020ax, RGB kb, Tempest Cooling, AI Gaming Laptop
# Price:  1,26,220
# Brand:  HP
# RAM:  16
# --------------------------------------------------------------------------------
# Title:  Thomson NEO 14.1 Inch IN-P14C Intel Celeron Dual Core N4020 Processor & Window 11 Notebook (8 GB RAM DDR4/ 256 GB SSD/Numeric Touch Pad/1MP Webcam/Silver)
# Price:  14,990
# Brand:  Thomson
# RAM:  8
# --------------------------------------------------------------------------------
# Title:  HP Chromebook X360 Intel Celeron N4020 14 inch(35.6 cm) Micro-Edge, Touchscreen, 2-in-1 Laptop (4GB RAM/64GB eMMC/Chrome OS/Intel UHD Graphics,1.49Kg), 14a-ca0506TU
# Price:  25,990
# Brand:  HP
# RAM:  4
# --------------------------------------------------------------------------------
# Title:  HP Pavilion x360, 13th Gen Intel Core i5-1335U (16GB DDR4, 1TB SSD) FHD, 14''/35.6 cm, Touchscreen 2-in-1, Win 11, Office 21, Silver, 1.51 kg, ek1010TU/1149tu, FPR, 5MP Camera, B&O, Backlit Laptop
# Price:  77,490
# Brand:  HP
# RAM:  16
# --------------------------------------------------------------------------------
# Title:  Lenovo V15 Intel Core i3 13th Gen (16GB RAM/512GB SSD/Windows 11 Home/Office 2024/Iron Grey) 15.6" FHD (1920x1080) Antiglare 250 Nits Thin & Light Laptop/1Y Onsite/1.65 kg, 83CCA08KIN
# Price:  N/A
# Brand:  Lenovo
# RAM:  16
# --------------------------------------------------------------------------------
# Title:  ULTIMUS APEX Laptop Intel Pentium Quad Core 8 GB DDR3 512 GB SSD Expandable~1TB 14.1 HD IPS Laptop Anti-Glare Ultra Thin Bezel 180° Hinge 3.0x3 USB HDMI SD Card Slot Win 11 Home 1.25KG Silver
# Price:  18,990
# Brand:  ULTIMUS
# RAM:  8
# --------------------------------------------------------------------------------
# Title:  Lenovo IdeaPad Slim 3, 12th Gen Intel Core i5-12450H (16GB LPDDR5, 512GB SSD), Anti-glare, FHD 15.6"(39.6cm), Win 11, Office Home 2024, Arctic Grey, 1.62Kg, 83ER00MDIN, Thin & Light, Backlit KB Laptop
# Price:  51,500
# Brand:  Lenovo
# RAM:  16
# --------------------------------------------------------------------------------
# Title:  ASUS Vivobook 15, Smartchoice, AMD Ryzen 7 5825U, 16GB RAM, 512GB SSD, FHD 15.6", Windows 11, Office Home 2024, Quiet Blue, 1.7Kg, M1502YA-BQ703WS, AMD Radeon iGPU, M365 Basic (1Year)*, 42Whr Laptop
# Price:  48,990
# Brand:  ASUS
# RAM:  16
# --------------------------------------------------------------------------------
# Title:  Lenovo IdeaPad 5 2-in-1 Convertible Laptop, Intel Core i7-13620H, 13th Gen, 16GB RAM, 512GB SSD, WUXGA OLED 400Nit, 14"/35.5cm, Windows 11, Office Home 2024, Grey, 1.5kg, 83KX004RIN, FPR, 1Yr ADP Free
# Price:  88,800
# Brand:  Lenovo
# RAM:  16
# --------------------------------------------------------------------------------
# Title:  Lenovo IdeaPad Slim 3 13th Gen Core i7-13620H 15.3" (38.8cm) WUXGA IPS Laptop (24GB RAM/1TB SSD/Win 11/Office 2024/Backlit/1Yr ADP Free/Top Metal Cover & IR Camera/Grey/1.6Kg),83K100TEIN
# Price:  90,990
# Brand:  Lenovo
# RAM:  24
# --------------------------------------------------------------------------------
# Title:  Lenovo V15 G4 15.6" FHD Business Laptop Computer, 13th Gen Intel 8-Core i5-13420H (Beat i7-1355U), 16GB DDR4 RAM, 512GB PCIe SSD, WiFi 6, Bluetooth 5.2, RJ-45, Type-C, HDMI, Windows 11 Pro, Wendbo
# Price:  57,900
# Brand:  Lenovo
# RAM:  16
# --------------------------------------------------------------------------------
# Title:  HP Victus, AMD Ryzen 7 7445HS, 4GB RTX 2050, 16GB DDR5(Upgradable) 512GB SSD, FHD, 144Hz, 300 nits, IPS, 15.6''/39.6cm, Win11, M365* Office24, Mica Silver, 2.29kg, fb3123AX, Backlit, Gaming Laptop
# Price:  62,990
# Brand:  HP
# RAM:  16
# --------------------------------------------------------------------------------
# Title:  HP 15, Intel Core Ultra 5 125H (16GB DDR5, 1TB SSD) FHD, IPS, 15.6''/39.6cm, Win11, M365 Basic(1yr)*Office24, Silver, 1.65kg, fd1354TU, Intel Arc Graphics, FHD Camera w/Shutter, AI Powered Laptop
# Price:  69,990
# Brand:  HP
# RAM:  16
# --------------------------------------------------------------------------------
# Title:  ASUS Gaming V16 (2025), 14th Gen,Intel Core 7 240H Gaming Laptop(RTX 5050-8GB/16GB RAM/512GB SSD/FHD+/16"/144Hz/Backlit Keyboard/Windows 11/M365*/Office Home 2024/Matte Black/1.95 Kg) V3607VH-RP038WS
# Price:  99,990
# Brand:  ASUS
# RAM:  16
# --------------------------------------------------------------------------------
# Title:  HP Omen, AMD Ryzen 9 8940HX, 8GB RTX 5060, 24GB DDR5(Upgradeable) 1TB SSD, 165Hz, 2k WUXGA, 3ms, 400 nits, 16''/40.6cm, Win11, M365* Office24, Black, 2.44kg, ap0181AX, Omen AI, RGB, AI Gaming Laptop
# Price:  1,55,490
# Brand:  HP
# RAM:  24
# --------------------------------------------------------------------------------
# Title:  HP 15, 13th Gen Intel Core i7-1355U (16GB DDR4, 512GB SSD) FHD, Anti-Glare, 15.6’’/39.6cm, Win11, M365(1yr)* Office 24, Silver, 1.59kg, Iris Xe, FHD Camera w/Shutter, Backlit Laptop fd0468tu/fd0515tu
# Price:  67,990
# Brand:  HP
# RAM:  16
# --------------------------------------------------------------------------------
# Title:  HP 15, 13th Gen Intel Core i5-1335U (16GB DDR4,512GB SSD) FHD, Anti-Glare,Micro-Edge, 15.6''/39.6cm, Win11, M365(1yr)* Office24, Silver,1.59kg, fd0467tu, Iris Xe, FHD Camera w/Shutter, Backlit Laptop
# Price:  54,990
# Brand:  HP
# RAM:  16
# --------------------------------------------------------------------------------
# Title:  ASUS TUF A15, AMD Ryzen 7 7445HS, Gaming Laptop(RTX 3050-4GB/75W TGP/32GB RAM/1TB SSD/FHD/15.6"/144Hz/Backlit Keyboard/48Whrs/Windows 11/Graphite Black/2.3 Kg) FA506NCG-HN250W
# Price:  82,990
# Brand:  ASUS
# RAM:  32
# --------------------------------------------------------------------------------
# Title:  Ultimus APEX TwinX 2-in-1 Touchscreen Laptop 16 GB RAM 512 GB SSD Intel® Core™ i3-1215U, 27.8 cm x2 FHD Display, Win 11, Wi-Fi 6, Bluetooth 5.2, USB 3.2 Type-C with Stylus 1.2Kg Silver
# Price:  45,990
# Brand:  Ultimus
# RAM:  16
# --------------------------------------------------------------------------------
# Title:  HP OmniBook 5 Flip, Intel Core 7 150U (16GB LPDDR5,1TB SSD) 2K, Micro-Edge, 300 nits, 14''/35.6cm, Convertible, Win 11, M365, Office 24, Glacier Silver,1.65kg, fp0690TU,Pen,5MP Camera w/Shutter Laptop
# Price:  92,990
# Brand:  HP
# RAM:  16
# --------------------------------------------------------------------------------

# %%
# EXtracting Rating improved
for product in products:
    rating_tag = product.find("span", {"class": "a-icon-alt"})
    rating_text = rating_tag.get_text(strip=True) if rating_tag else "N/A"
    print("Rating: ",rating_text)
    print("-"*80)
# Out:
# Rating:  3.7 out of 5 stars
# --------------------------------------------------------------------------------
# Rating:  3.7 out of 5 stars
# --------------------------------------------------------------------------------
# Rating:  4.0 out of 5 stars
# --------------------------------------------------------------------------------
# Rating:  3.0 out of 5 stars
# --------------------------------------------------------------------------------
# Rating:  3.9 out of 5 stars
# --------------------------------------------------------------------------------
# Rating:  3.9 out of 5 stars
# --------------------------------------------------------------------------------
# Rating:  3.9 out of 5 stars
# --------------------------------------------------------------------------------
# Rating:  3.4 out of 5 stars
# --------------------------------------------------------------------------------
# Rating:  4.2 out of 5 stars
# --------------------------------------------------------------------------------
# Rating:  4.3 out of 5 stars
# --------------------------------------------------------------------------------
# Rating:  4.2 out of 5 stars
# --------------------------------------------------------------------------------
# Rating:  4.1 out of 5 stars
# --------------------------------------------------------------------------------
# Rating:  4.5 out of 5 stars
# --------------------------------------------------------------------------------
# Rating:  4.3 out of 5 stars
# --------------------------------------------------------------------------------
# Rating:  4.0 out of 5 stars
# --------------------------------------------------------------------------------
# Rating:  5.0 out of 5 stars
# --------------------------------------------------------------------------------
# Rating:  4.2 out of 5 stars
# --------------------------------------------------------------------------------
# Rating:  4.0 out of 5 stars
# --------------------------------------------------------------------------------
# Rating:  3.9 out of 5 stars
# --------------------------------------------------------------------------------
# Rating:  4.2 out of 5 stars
# --------------------------------------------------------------------------------
# Rating:  2.9 out of 5 stars
# --------------------------------------------------------------------------------
# Rating:  4.5 out of 5 stars
# --------------------------------------------------------------------------------

# %%
#extract storage from the title
for product in data:
    title = product["Title"]
    storage_match = re.search(r'(\d+)\s*GB\s*(SSD|HDD)', title)
    storage = storage_match.group(1) if storage_match else "N/A"
    product["Storage"] = storage
for product in data:
    print("Storage: ",product["Storage"])
    print("-"*80)
# Out:
# Storage:  512
# --------------------------------------------------------------------------------
# Storage:  N/A
# --------------------------------------------------------------------------------
# Storage:  N/A
# --------------------------------------------------------------------------------
# Storage:  128
# --------------------------------------------------------------------------------
# Storage:  N/A
# --------------------------------------------------------------------------------
# Storage:  512
# --------------------------------------------------------------------------------
# Storage:  512
# --------------------------------------------------------------------------------
# Storage:  N/A
# --------------------------------------------------------------------------------
# Storage:  256
# --------------------------------------------------------------------------------
# Storage:  512
# --------------------------------------------------------------------------------
# Storage:  512
# --------------------------------------------------------------------------------
# Storage:  512
# --------------------------------------------------------------------------------
# Storage:  N/A
# --------------------------------------------------------------------------------
# Storage:  512
# --------------------------------------------------------------------------------
# Storage:  512
# --------------------------------------------------------------------------------
# Storage:  128
# --------------------------------------------------------------------------------
# Storage:  512
# --------------------------------------------------------------------------------
# Storage:  512
# --------------------------------------------------------------------------------
# Storage:  256
# --------------------------------------------------------------------------------
# Storage:  512
# --------------------------------------------------------------------------------
# Storage:  512
# --------------------------------------------------------------------------------
# Storage:  512
# --------------------------------------------------------------------------------
# Storage:  N/A
# --------------------------------------------------------------------------------
# Storage:  512
# --------------------------------------------------------------------------------
# Storage:  N/A
# --------------------------------------------------------------------------------
# Storage:  256
# --------------------------------------------------------------------------------
# Storage:  N/A
# --------------------------------------------------------------------------------
# Storage:  N/A
# --------------------------------------------------------------------------------
# Storage:  512
# --------------------------------------------------------------------------------
# Storage:  512
# --------------------------------------------------------------------------------
# Storage:  512
# --------------------------------------------------------------------------------
# Storage:  512
# --------------------------------------------------------------------------------
# Storage:  512
# --------------------------------------------------------------------------------
# Storage:  N/A
# --------------------------------------------------------------------------------
# Storage:  N/A
# --------------------------------------------------------------------------------
# Storage:  512
# --------------------------------------------------------------------------------
# Storage:  N/A
# --------------------------------------------------------------------------------
# Storage:  512
# --------------------------------------------------------------------------------
# Storage:  N/A
# --------------------------------------------------------------------------------
# Storage:  512
# --------------------------------------------------------------------------------
# Storage:  512
# --------------------------------------------------------------------------------
# Storage:  N/A
# --------------------------------------------------------------------------------
# Storage:  512
# --------------------------------------------------------------------------------
# Storage:  N/A
# --------------------------------------------------------------------------------

# %%
#extract color from the title
for product in data:
    title = product["Title"]
    color_match = re.search(r'\b(Black|Silver|Gray|White|Blue|Red|Green|Yellow|Pink)\b', title, re.IGNORECASE)
    color = color_match.group(1) if color_match else "N/A"
    product["Color"] = color
for product in data:
    print("Color: ",product["Color"])
    print("-"*80)
# Out:
# Color:  Silver
# --------------------------------------------------------------------------------
# Color:  N/A
# --------------------------------------------------------------------------------
# Color:  Black
# --------------------------------------------------------------------------------
# Color:  N/A
# --------------------------------------------------------------------------------
# Color:  Blue
# --------------------------------------------------------------------------------
# Color:  Silver
# --------------------------------------------------------------------------------
# Color:  Silver
# --------------------------------------------------------------------------------
# Color:  Blue
# --------------------------------------------------------------------------------
# Color:  Silver
# --------------------------------------------------------------------------------
# Color:  Black
# --------------------------------------------------------------------------------
# Color:  N/A
# --------------------------------------------------------------------------------
# Color:  N/A
# --------------------------------------------------------------------------------
# Color:  Silver
# --------------------------------------------------------------------------------
# Color:  Silver
# --------------------------------------------------------------------------------
# Color:  Black
# --------------------------------------------------------------------------------
# Color:  Silver
# --------------------------------------------------------------------------------
# Color:  Silver
# --------------------------------------------------------------------------------
# Color:  Silver
# --------------------------------------------------------------------------------
# Color:  Silver
# --------------------------------------------------------------------------------
# Color:  N/A
# --------------------------------------------------------------------------------
# Color:  Silver
# --------------------------------------------------------------------------------
# Color:  N/A
# --------------------------------------------------------------------------------
# Color:  Silver
# --------------------------------------------------------------------------------
# Color:  N/A
# --------------------------------------------------------------------------------
# Color:  Black
# --------------------------------------------------------------------------------
# Color:  Silver
# --------------------------------------------------------------------------------
# Color:  N/A
# --------------------------------------------------------------------------------
# Color:  Silver
# --------------------------------------------------------------------------------
# Color:  N/A
# --------------------------------------------------------------------------------
# Color:  Silver
# --------------------------------------------------------------------------------
# Color:  N/A
# --------------------------------------------------------------------------------
# Color:  Blue
# --------------------------------------------------------------------------------
# Color:  N/A
# --------------------------------------------------------------------------------
# Color:  N/A
# --------------------------------------------------------------------------------
# Color:  N/A
# --------------------------------------------------------------------------------
# Color:  Silver
# --------------------------------------------------------------------------------
# Color:  Silver
# --------------------------------------------------------------------------------
# Color:  Black
# --------------------------------------------------------------------------------
# Color:  Black
# --------------------------------------------------------------------------------
# Color:  Silver
# --------------------------------------------------------------------------------
# Color:  Silver
# --------------------------------------------------------------------------------
# Color:  Black
# --------------------------------------------------------------------------------
# Color:  Silver
# --------------------------------------------------------------------------------
# Color:  Silver
# --------------------------------------------------------------------------------

# %%
#extract windows veraion from the title improved version
for product in data:
    title = product["Title"]
    windows_match = re.search(r'\b(Windows\s*\d{2}|Windows\s*11|Windows\s*10|Windows\s*8|Windows\s*7)\b', title, re.IGNORECASE)
    windows_version = windows_match.group(1) if windows_match else "N/A"
    product["Windows_Version"] = windows_version
    print("Windows Version: ",product["Windows_Version"])
    print("-"*80)
# Out:
# Windows Version:  N/A
# --------------------------------------------------------------------------------
# Windows Version:  N/A
# --------------------------------------------------------------------------------
# Windows Version:  N/A
# --------------------------------------------------------------------------------
# Windows Version:  Windows 11
# --------------------------------------------------------------------------------
# Windows Version:  N/A
# --------------------------------------------------------------------------------
# Windows Version:  N/A
# --------------------------------------------------------------------------------
# Windows Version:  N/A
# --------------------------------------------------------------------------------
# Windows Version:  N/A
# --------------------------------------------------------------------------------
# Windows Version:  Windows 11
# --------------------------------------------------------------------------------
# Windows Version:  N/A
# --------------------------------------------------------------------------------
# Windows Version:  Windows 11
# --------------------------------------------------------------------------------
# Windows Version:  Windows 11
# --------------------------------------------------------------------------------
# Windows Version:  N/A
# --------------------------------------------------------------------------------
# Windows Version:  Windows 11
# --------------------------------------------------------------------------------
# Windows Version:  Windows 11
# --------------------------------------------------------------------------------
# Windows Version:  N/A
# --------------------------------------------------------------------------------
# Windows Version:  N/A
# --------------------------------------------------------------------------------
# Windows Version:  Windows 11
# --------------------------------------------------------------------------------
# Windows Version:  Windows 11
# --------------------------------------------------------------------------------
# Windows Version:  Windows 11
# --------------------------------------------------------------------------------
# Windows Version:  N/A
# --------------------------------------------------------------------------------
# Windows Version:  N/A
# --------------------------------------------------------------------------------
# Windows Version:  N/A
# --------------------------------------------------------------------------------
# Windows Version:  Windows 11
# --------------------------------------------------------------------------------
# Windows Version:  N/A
# --------------------------------------------------------------------------------
# Windows Version:  N/A
# --------------------------------------------------------------------------------
# Windows Version:  N/A
# --------------------------------------------------------------------------------
# Windows Version:  N/A
# --------------------------------------------------------------------------------
# Windows Version:  Windows 11
# --------------------------------------------------------------------------------
# Windows Version:  N/A
# --------------------------------------------------------------------------------
# Windows Version:  N/A
# --------------------------------------------------------------------------------
# Windows Version:  Windows 11
# --------------------------------------------------------------------------------
# Windows Version:  Windows 11
# --------------------------------------------------------------------------------
# Windows Version:  N/A
# --------------------------------------------------------------------------------
# Windows Version:  Windows 11
# --------------------------------------------------------------------------------
# Windows Version:  N/A
# --------------------------------------------------------------------------------
# Windows Version:  N/A
# --------------------------------------------------------------------------------
# Windows Version:  Windows 11
# --------------------------------------------------------------------------------
# Windows Version:  N/A
# --------------------------------------------------------------------------------
# Windows Version:  N/A
# --------------------------------------------------------------------------------
# Windows Version:  N/A
# --------------------------------------------------------------------------------
# Windows Version:  Windows 11
# --------------------------------------------------------------------------------
# Windows Version:  N/A
# --------------------------------------------------------------------------------
# Windows Version:  N/A
# --------------------------------------------------------------------------------
